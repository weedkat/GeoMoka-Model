# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch
from dataloader.ISPRSPostdam import ISPRSPostdam

# %%
# %load_ext autoreload
isprs = ISPRSPostdam('dataset/ISPRS-Postdam/splits/test.csv')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
isprs[0]
# Out:
# /home/ubuntu/Projects/GeoMoka-model/.venv/lib/python3.10/site-packages/rasterio/__init__.py:356: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# (array([[[171, 173, 163],
#          [154, 154, 142],
#          [179, 179, 169],
#          ...,
#          [ 87, 112, 106],
#          [ 87, 111, 105],
#          [ 88, 111, 106]],
#
#         [[158, 160, 151],
#          [147, 148, 137],
#          [172, 175, 163],
#          ...,
#          [ 87, 113, 106],
#          [ 85, 108, 101],
#          [ 85, 107, 101]],
#
#         [[145, 148, 139],
#          [145, 148, 137],
#          [174, 177, 167],
#          ...,
#          [ 86, 112, 105],
#          [ 83, 107,  99],
#          [ 85, 108, 102]],
#
#         ...,
#
#         [[141, 157, 153],
#          [133, 146, 142],
#          [136, 148, 145],
#          ...,
#          [ 83, 107, 100],
# ...
